# %%
from PIL import Image

# %%
word_matrix = Image.open('word_matrix.png')
mask = Image.open('mask.png')

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FB792567790>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x7FB792567210>

# %%
mask.size
# Out:
# (505, 251)

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
word_matrix = word_matrix.resize((505,251))

# %%
word_matrix.size
# Out:
# (505, 251)

# %%
word_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251 at 0x7FB7925F9FD0>

# %%
mask.putalpha(150)

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x7FB792567210>

# %%
word_matrix.paste(im=mask,box=(0,0), mask=mask)

# %%
word_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251 at 0x7FB7925F9FD0>

# %% [markdown]
# # Solution!

# %%
from PIL import Image

# %%
words = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FB7925EFE50>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x7FB792567250>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask = mask.resize((1015,559))

# %%
mask.size
# Out:
# (1015, 559)

# %%
mask.putalpha(200)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x7FB792562890>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FB7925EFE50>
